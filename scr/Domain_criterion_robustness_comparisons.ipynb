# %%
import numpy as np
from scipy.optimize import brentq
import math
from scipy.optimize import minimize
import random

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D # <--- This is important for 3d plotting 

import csv
import plotly.express as px
import plotly.graph_objects as go

# %%
domain_50s = pd.read_csv('Domain_50solutions_(25.11.2020)50s.csv')
domain_15s = pd.read_csv('Domain_50solutions_(25.11.2020)15s.csv')
domain_9s = pd.read_csv(r'C:\Users\babshava\pyDMDU\robust_optimization_comparison\src\exp2(Eker2018_scenarios)\Domain_50solutions_(28.10.2020)9s.csv')
domain_5s = pd.read_csv(r'C:\Users\babshava\pyDMDU\robust_optimization_comparison\src\exp2(Eker2018_scenarios)\Domain_49solutions_(28.10.2020)5s.csv')
domain_s1 = pd.read_csv('Domain_56solutions_(28.10.2020)s1.csv')
domain_s2 = pd.read_csv('Domain_59solutions_(28.10.2020)s2.csv')
domain_s3 = pd.read_csv('Domain_58solutions_(28.10.2020)s3.csv')
domain_s4 = pd.read_csv('Domain_64solutions_(28.10.2020)s4.csv')
domain_s5 = pd.read_csv('Domain_48solutions_(28.10.2020)s5.csv')

# %%
#Utility robustness
axes = plt.gca()
axes.set_ylim([0,1.05])
axes.set_xlim([0,100])
plt.plot(np.arange(1,50+1)*100/50,domain_50s.rdc_u, color = "green")
plt.plot(np.arange(1,50+1)*100/50,domain_9s.rdc_u, color = "red")
plt.plot(np.arange(1,49+1)*100/49,domain_5s.rdc_u, color = "blue")
plt.plot(np.arange(1,50+1)*100/50,domain_s1.rdc_u, color = "gray")
plt.plot(np.arange(1,59+1)*100/59,domain_s2.rdc_u, color = "gray")
plt.plot(np.arange(1,58+1)*100/58,domain_s3.rdc_u, color = "gray")
plt.plot(np.arange(1,64+1)*100/64,domain_s4.rdc_u, color = "gray")
plt.plot(np.arange(1,48+1)*100/48,domain_s5.rdc_u, color = "gray")
plt.xlabel("Percentage of solutions") 
plt.ylabel("Fraction Utility") 
plt.show()

# %%
#Reliability robustness
axes = plt.gca()
axes.set_ylim([0,1.05])
axes.set_xlim([0,100])
plt.plot(np.arange(1,50+1)*100/50,domain_50s.rdc_rel, color = "green")
plt.plot(np.arange(1,50+1)*100/50,domain_9s.rdc_rel, color = "red")
plt.plot(np.arange(1,49+1)*100/49,domain_5s.rdc_rel, color = "blue")
plt.plot(np.arange(1,50+1)*100/50,domain_s1.rdc_rel, color = "gray")
plt.plot(np.arange(1,59+1)*100/59,domain_s2.rdc_rel, color = "gray")
plt.plot(np.arange(1,58+1)*100/58,domain_s3.rdc_rel, color = "gray")
plt.plot(np.arange(1,64+1)*100/64,domain_s4.rdc_rel, color = "gray")
plt.plot(np.arange(1,48+1)*100/48,domain_s5.rdc_rel, color = "gray")
plt.xlabel("Percentage of solutions") 
plt.ylabel("Fraction Reliability") 
plt.show()

# %%
#Pollution robustness
axes = plt.gca()
axes.set_ylim([0,1.05])
axes.set_xlim([0,100])
plt.plot(np.arange(1,50+1)*100/50,domain_50s.rdc_pol, color = "green")
plt.plot(np.arange(1,50+1)*100/50,domain_9s.rdc_pol, color = "red")
plt.plot(np.arange(1,49+1)*100/49,domain_5s.rdc_pol, color = "blue")
plt.plot(np.arange(1,50+1)*100/50,domain_s1.rdc_pol, color = "gray")
plt.plot(np.arange(1,59+1)*100/59,domain_s2.rdc_pol, color = "gray")
plt.plot(np.arange(1,58+1)*100/58,domain_s3.rdc_pol, color = "gray")
plt.plot(np.arange(1,64+1)*100/64,domain_s4.rdc_pol, color = "gray")
plt.plot(np.arange(1,48+1)*100/48,domain_s5.rdc_pol, color = "gray")
plt.xlabel("Percentage of solutions") 
plt.ylabel("Fraction Pollution") 
plt.show()

# %%
#Inertia robustness
axes = plt.gca()
axes.set_ylim([0,1.05])
axes.set_xlim([0,100])
plt.plot(np.arange(1,50+1)*100/50,domain_50s.rdc_in, color = "green")
plt.plot(np.arange(1,50+1)*100/50,domain_9s.rdc_in, color = "red")
plt.plot(np.arange(1,49+1)*100/49,domain_5s.rdc_in, color = "blue")
plt.plot(np.arange(1,50+1)*100/50,domain_s1.rdc_in, color = "gray")
plt.plot(np.arange(1,59+1)*100/59,domain_s2.rdc_in, color = "gray")
plt.plot(np.arange(1,58+1)*100/58,domain_s3.rdc_in, color = "gray")
plt.plot(np.arange(1,64+1)*100/64,domain_s4.rdc_in, color = "gray")
plt.plot(np.arange(1,48+1)*100/48,domain_s5.rdc_in, color = "gray")
plt.xlabel("Percentage of solutions") 
plt.ylabel("Fraction Inertia") 
plt.show()
